# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

women_degrees = pd.read_csv(r'C:\Users\WWCOLL\Documents\dataquest\women_degrees.csv')

stem_cats = ['Engineering','Computer Science','Psychology','Biology','Physical Sciences','Math and Statistics']
lib_arts_cats = ['Foreign Languages','English','Communications and Journalism','Art and Performance','Social Sciences and History']
other_cats = ['Health Professions','Public Administration','Education','Agriculture','Business','Architecture']

fig = plt.figure(figsize=(18,3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[sp]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[sp]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False)
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
plt.show()

# %%
stem_cats = ['Engineering','Computer Science','Psychology','Biology','Physical Sciences','Math and Statistics']
lib_arts_cats = ['Foreign Languages','English','Communications and Journalism','Art and Performance','Social Sciences and History']
other_cats = ['Health Professions','Public Administration','Education','Agriculture','Business','Architecture']

fig = plt.figure(figsize=(16,25))

for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[cat_index]],label='Men')
        #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False)
        
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False)
    
for sp in range(2,18,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False)

plt.show()

# %% [markdown]
# # Hiding x-axis labels and adding line labels

# %%
stem_cats = ['Engineering','Computer Science','Psychology','Biology','Physical Sciences','Math and Statistics']
lib_arts_cats = ['Foreign Languages','English','Communications and Journalism','Art and Performance','Social Sciences and History']
other_cats = ['Health Professions','Public Administration','Education','Agriculture','Business','Architecture']

fig = plt.figure(figsize=(16,25))

for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[cat_index]],label='Men')
        #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #text labels
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom=True)
        
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #text labels
    if sp == 1:
        ax.text(2005,75,'Women')
        ax.text(2005,20,'Men')
    elif sp == 13:
        ax.text(1987,65,'Men')
        ax.text(1987,35,'Women')
        ax.tick_params(labelbottom=True)
    
for sp in range(2,18,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #text labels
    if sp == 2:
        ax.text(2005,70,'Women')
        ax.text(2005,25,'Men')
    if sp == 17:
        ax.text(2005,70,'Men')
        ax.text(2005,30,'Women')
        ax.tick_params(labelbottom=True)
        
plt.show()

# %% [markdown]
# # Setting y-axis labels

# %%
stem_cats = ['Engineering','Computer Science','Psychology','Biology','Physical Sciences','Math and Statistics']
lib_arts_cats = ['Foreign Languages','English','Communications and Journalism','Art and Performance','Social Sciences and History']
other_cats = ['Health Professions','Public Administration','Education','Agriculture','Business','Architecture']

fig = plt.figure(figsize=(16,25))

for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[cat_index]],label='Men')
        #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #removing y labels
    ax.set_yticks([0,100])
    #text labels
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom=True)
        
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #removing y labels
    ax.set_yticks([0,100])
    #text labels
    if sp == 1:
        ax.text(2005,75,'Women')
        ax.text(2005,20,'Men')
    elif sp == 13:
        ax.text(1987,65,'Men')
        ax.text(1987,35,'Women')
        ax.tick_params(labelbottom=True)
    
for sp in range(2,18,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[cat_index]],label='Women')
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[cat_index]],label='Men')
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    #removing y labels
    ax.set_yticks([0,100])
    #text labels
    if sp == 2:
        ax.text(2005,70,'Women')
        ax.text(2005,25,'Men')
    if sp == 17:
        ax.text(2005,70,'Men')
        ax.text(2005,30,'Women')
        ax.tick_params(labelbottom=True)
        
plt.show()

# %% [markdown]
# # Adding a horizontal line and increased linewidth

# %%
stem_cats = ['Engineering','Computer Science','Psychology','Biology','Physical Sciences','Math and Statistics']
lib_arts_cats = ['Foreign Languages','English','Communications and Journalism','Art and Performance','Social Sciences and History']
other_cats = ['Health Professions','Public Administration','Education','Agriculture','Business','Architecture']

fig = plt.figure(figsize=(16,25))

for sp in range(0,18,3):
    cat_index = int(sp/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[stem_cats[cat_index]],label='Women',linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[stem_cats[cat_index]],label='Men',linewidth=3)
    
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[cat_index])
    
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    
    #removing y labels
    ax.set_yticks([0,100])
    
    #add a horizontal line
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.5)
    
    #text labels
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 15:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        ax.tick_params(labelbottom=True)
        
for sp in range(1,16,3):
    cat_index = int((sp-1)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[lib_arts_cats[cat_index]],label='Women',linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[lib_arts_cats[cat_index]],label='Men',linewidth=3)
    
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[cat_index])
    
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    
    #removing y labels
    ax.set_yticks([0,100])
    
    #add a horizontal line
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.5)
    
    #text labels
    if sp == 1:
        ax.text(2005,75,'Women')
        ax.text(2005,20,'Men')
    elif sp == 13:
        ax.text(1987,65,'Men')
        ax.text(1987,35,'Women')
        ax.tick_params(labelbottom=True)
    
for sp in range(2,18,3):
    cat_index = int((sp-2)/3)
    ax = fig.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'],women_degrees[other_cats[cat_index]],label='Women',linewidth=3)
    ax.plot(women_degrees['Year'],100-women_degrees[other_cats[cat_index]],label='Men',linewidth=3)
    
    #get ride of spines
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[cat_index])
    
    #tick params
    ax.tick_params(bottom=False,top=False,left=False,right=False,labelbottom=False)
    
    #removing y labels
    ax.set_yticks([0,100])
    
    #add a horizontal line
    ax.axhline(50,c=(171/255,171/255,171/255),alpha=0.5)
    
    #text labels
    if sp == 2:
        ax.text(2005,70,'Women')
        ax.text(2005,25,'Men')
    if sp == 17:
        ax.text(2005,70,'Men')
        ax.text(2005,30,'Women')
        ax.tick_params(labelbottom=True)
    
plt.savefig('gender_degrees.png')
plt.show()

# %%
plt.plot(women_degrees['Year'],women_degrees['Business'])
plt.savefig('biology_degrees.png')
