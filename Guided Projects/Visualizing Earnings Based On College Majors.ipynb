# %% [markdown]
# # Guided Project; Visualizing Earnings Based On College Majors
#
# #### dataset:
# [fivethirtyeight recent grads](https://github.com/fivethirtyeight/data/tree/master/college-majors)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv(r'C:\Users\WWCOLL\Documents\dataquest\recent_grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head())
print(recent_grads.tail())
recent_grads.describe()
raw_data_count = recent_grads.count()
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.count()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.plot(x='Sample_size',y='Median',kind='scatter',title='Sample_size vs. Median')

# %% [markdown]
# the larger the sample size, the more the data seems to reflect a median of $40,000

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter',title='Sample_size vs. Unemployment_rate')

# %% [markdown]
# similar to the prior graph, this one shows that the larger the sample size the more consistently an unemployment rate of ~0.075 is reflected

# %%
recent_grads.plot(x='Full_time',y='Median',kind='scatter',title='Full_time vs. Median')

# %% [markdown]
# most studies could only get less than 50,000 full time employees surveyed, but both the larger full time employee studies as well as the cluster of smaller studies reflect a median ~35,000
# #### this does show that the the larger the number of employees you ahve is, teh lower the median, smaller companies ahave the capability to pay their median employees more seemingly

# %%
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter',title='ShareWomen vs. Unemployment_rate')

# %% [markdown]
# this shows no corrleation between % women employed and the unemployment rate, might show a very very weak positive correlation between 0.2-0.6

# %%
recent_grads.plot(x='Men',y='Median',kind='scatter',title='Men vs. Median')

# %% [markdown]
# this looks the same as the womens graph below (they are clearly meant to be compared) although one of the studies below was able to get about 300,000 women whil teh largest gruop for men seems to onyl be about 175,000.

# %%
recent_grads.plot(x='Women',y='Median',kind='scatter',title='Women vs. Median')

# %%
"""cols=['Sample_size','Median','Full_time','ShareWomen']

fig=plt.figure(figsize=(5,12))
for r in range(1,5):
    ax = fig.add_subplot(4,1,r)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)"""
# Out:
# "cols=['Sample_size','Median','Full_time','ShareWomen']\n\nfig=plt.figure(figsize=(5,12))\nfor r in range(1,5):\n    ax = fig.add_subplot(4,1,r)\n    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)"

# %%
recent_grads['Sample_size'].hist()

# %%
recent_grads['Median'].hist(bins=10, range=(20000,45000))

# %% [markdown]
# the most common median salary is $ 35,000 to $ 37,500

# %%
recent_grads['Employed'].hist()

# %%
recent_grads['Full_time'].hist()

# %%
recent_grads['ShareWomen'].hist(bins=5)

# %% [markdown]
# "about 25% of majors contain 40-60% female students"
# - 0-20% Share of Women account for about 8% of majors
# - 20-40% share of women account for about 23% of majors
# - 40-60% share of women account for about 25% of majors
# - 60-80% share of women account for about 32% of majors
# - 80-100% share of women account for about 12% of majors

# %%
recent_grads['Unemployment_rate'].hist()

# %%
recent_grads['Men'].hist()

# %%
recent_grads['Women'].hist(bins=50, range=(0,50000))

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000291567D7748>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029156BB8C88>,
# ...
#       dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
"""better to use below so we can specify the labels"""
recent_grads.head(10).plot.bar(x='Major',y='ShareWomen',legend=False)
"""recent_grads[:10]"""

# %%
recent_grads.tail(10).plot.bar(x='Major',y='ShareWomen',legend=False)
"""recent_grads[163:]"""
# Out:
# 'recent_grads[163:]'

# %%
recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate',legend=False)

# %%
recent_grads[163:].plot.bar(x='Major',y='Unemployment_rate',legend=False)

# %% [markdown]
# #### grouped bar plot compare number of men and women in each category of majors

# %%
recent_grads[:20].plot.bar(x='Major_category',y=['Men','Women'],figsize=(20,20))

# %%
recent_grads.plot.box(y='Median')
recent_grads.plot.box(y='Unemployment_rate')

# %% [markdown]
# ### for the hexbin, choosing cells that have clusetered scatters frmo earlier:
# #### Men/Women vs. Median

# %%
recent_grads.plot.hexbin(x='Men',y='Median',gridsize=25)
recent_grads.plot.hexbin(x='Women',y='Median',gridsize=25)
